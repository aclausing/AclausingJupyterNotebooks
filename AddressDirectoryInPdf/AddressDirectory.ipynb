# %%
# Alice Clausing May 2023
# Gnu General Public License V3

# %%
import csv
from datetime import datetime
from os import path
from reportlab.lib.pagesizes import letter
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer

# %%
# To create church directory:
# 1) Delete old export.csv file
# 2) Run "Church Directory Data as CSV" report in ChurchTrac for "Active Names" only, export in CSV format
# 3) Copy export.csv file to the same folder where the Jupyter notebook is

# %%
# Generate church address list as PDF
# Text file is also created for debugging purposes, not intended for distribution.

EXPORT_PATH = "export.csv"
MAX_LINE_LEN = 70
NBSP10 = "&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"

# file creation timestamp in float
c_time = path.getctime(EXPORT_PATH)
# convert creation timestamp into DateTime object
dt_c = datetime.fromtimestamp(c_time)

with open(EXPORT_PATH, newline='') as csvfile:
    # ChurchTrac doesn't provide column header for "Address 2" field, so we have to specify fieldnames
    export_reader = csv.DictReader(csvfile, fieldnames=('Formal', 'Primary', 'Address', 'Address2', 'Email', 'Comment'))
    f = open("church_directory.txt", "wt")
    
    # PDF setup
    doc = SimpleDocTemplate(
            "church_directory.pdf",
            pagesize=letter,
            rightMargin=50, leftMargin=50,
            topMargin=25, bottomMargin=25,
            )
    styles = getSampleStyleSheet()
    flowables = []   # list of items to be included in PDF
    bodyStyle = ParagraphStyle('Body', fontSize=12)
    para = Paragraph("Beaver UCC Directory" + NBSP10 + NBSP10 + NBSP10 + NBSP10 + NBSP10 + NBSP10 + NBSP10 + dt_c.strftime("%d %B %Y"), style=bodyStyle)
    flowables.append(para)    
    spacer = Spacer(1, 0.25*inch)
    flowables.append(spacer)
    
    first_row = True
    for row in export_reader:
        # print(row)   # debug - print dictionary contents
        # Skip column header row
        if first_row:
            first_row = False
        else:    
            family_name = row['Formal']

            # No column header for Address 2 when exported from ChurchTrac, but it's the 4th column in spreadsheet
            address2 = list(row.values())[3]
            address = row['Address'] + ', ' + address2 + '\n'
               
            f.write(family_name)
            f.write(address)
            if len(family_name) + len(address) < MAX_LINE_LEN:
                para = Paragraph(family_name + NBSP10 + address, style=bodyStyle)
                flowables.append(para)
            else:
                para = Paragraph(family_name, style=bodyStyle)
                flowables.append(para)
                para = Paragraph(address, style=bodyStyle)
                flowables.append(para)

            primary_phone = row['Primary']
            comment = row['Comment']
            if primary_phone in comment:
                phone_email = comment
            else:
                phone_email = primary_phone
                if len(comment) > 0:
                    phone_email = phone_email + NBSP10 + comment
            email = row['Email']
            if len(email) > 0:
                if len(phone_email) == 0:
                    phone_email = email
                elif len(phone_email) + 10 + len(email) > MAX_LINE_LEN:
                    f.write(phone_email + '\n')
                    para = Paragraph(phone_email, style=bodyStyle)
                    flowables.append(para) 
                    phone_email = email
                else:
                    phone_email = phone_email + NBSP10 + email
            if len(phone_email) > 0:        
                f.write(phone_email + '\n')  
                para = Paragraph(phone_email, style=bodyStyle)
                flowables.append(para) 
            f.write('\n')
            spacer = Spacer(1, 0.25*inch)
            flowables.append(spacer)
    f.close()  
    doc.build(flowables)
csvfile.close()

# %%
csvfile.close()
f.close()

# %%
import csv
import random
import re

# %%
def obfuscate(str_in: str) -> str:
    """Replaces digit with random digit, alpha letter with random letter, leaving 1st character alone"""
    str_out = str_in[0]
    str_idx = 1
    str_len = len(str_in)
    while str_idx < str_len:
        char_in = str_in[str_idx]
        # print("obfuscate: str_idx=", str_idx, ", char_in=xxx", char_in, "xxx")   # debug
        if char_in.islower():
            str_out = str_out + random.choice("abcdefghijklmnopqrstuvwxyz")
        elif char_in.isupper(): 
            char_obf = random.choice("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
            str_out = str_out + char_obf
        elif char_in.isdigit():
            str_out = str_out + random.choice("0123456789")
        else:   # whitespace and punctuation characters do not change
            str_out = str_out + char_in
        str_idx = str_idx + 1 
    # print("obfuscate: str_in=xxx", str_in, "xxx, str_out=xxx", str_out, "xxx")  # debug  
    return str_out

# %%
def obfuscate_line(str_in: str, ignore_seq: list) -> str:
    """
    Obfuscates words and numbers in line.

    Input arguments:
    str_in: line to be obfuscated 
    ignore: sequence of words to ignore in line, i.e., words which will not be obfuscated. ignore_seq words should be in upper case, but the comparison is case-insensitive.
    """
    retstr = ""   # return string
    # See https://stackoverflow.com/questions/2136556/in-python-how-do-i-split-a-string-and-keep-the-separators
    # \W means "non-word" in regular expression
    # If capturing parentheses are used in pattern, then the text of all groups in the pattern are also returned as part of the resulting list.
    tokens_and_separators = re.split('(\W)', str_in)
    # if len(str_in) > 0:                                    # debug
    #    print("obfuscate_line: ", tokens_and_separators)   # debug
    for item in tokens_and_separators:
        if item.upper() in ignore_seq:
            retstr = retstr + item
        elif item.isalnum():
            retstr = retstr + obfuscate(item)
        else:
            retstr = retstr + item
    #if len(str_in) > 0:                                    # debug
    #    print("obfuscate_line returns ", retstr)           # debug
    return retstr

# %%
# Obfuscate the ChurchTrac CSV file, so it can be posted publicly as sample data file for this Jupyter notebook.
EXPORT_PATH = "export.csv"
FIELD_NAMES = ('Formal', 'Primary', 'Address', 'Address2', 'Email', 'Comment')

with open(EXPORT_PATH, newline='') as csvfile:
    # ChurchTrac doesn't provide column header for "Address 2" field, so we have to specify fieldnames
    export_reader = csv.DictReader(csvfile, FIELD_NAMES)
    f = open("church_directory.txt", "wt")
    
    with open('obfuscated.csv', 'w', newline='') as obffile:
        obfwriter = csv.writer(obffile, delimiter=',', dialect='excel',
                                quoting=csv.QUOTE_MINIMAL)

        first_row = True
        for row in export_reader:
            # print(row)   # debug - print ChurchTrac CSV row as dictionary
            if first_row:
                obfwriter.writerow(FIELD_NAMES)
                first_row = False
            else:    
                formal = obfuscate_line(row['Formal'], ('AND'))
                primary = obfuscate_line(row['Primary'], ())
                address = obfuscate_line(row['Address'], ("APT", "BOX", "CT", "DR", "DRIVE", "PO", "RD", "ST"))
                
                # No column header for Address 2 when exported from ChurchTrac, but it's the 4th column in spreadsheet
                address2 = obfuscate_line(list(row.values())[3], ("OH"))
                
                email = obfuscate_line(row['Email'], ("COM", "NET", "ORG"))
                comment = obfuscate_line(row['Comment'], ("CELL"))
                
                obfwriter.writerow([formal, primary, address, address2, email, comment])
# Out:
# obfuscate_line:  ['Paul', ' ', 'and', ' ', 'Staci', ' ', 'Auer']
# obfuscate_line returns  Plzi and Sngna Acqf
# obfuscate_line:  ['3848', ' ', 'MESQUITE', ' ', 'DR']
# obfuscate_line returns  3018 MDRTCLJG DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45440', '-', '3498']
# obfuscate_line returns  BMGZJNVYKOT OH 40134-3298
# obfuscate_line:  ['Ellen', ' ', 'Bagley']
# obfuscate_line returns  Eptuj Bqkped
# obfuscate_line:  ['457', ' ', 'BIG', ' ', 'STONE', ' ', 'DR']
# obfuscate_line returns  437 BRE STCWV DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '5704']
# obfuscate_line returns  BLPMOTYRIMH OH 45620-5235
# obfuscate_line:  ['Bill', ' ', 'and', ' ', 'Karen', ' ', 'Barger']
# obfuscate_line returns  Bspj and Kgswl Betdbt
# obfuscate_line:  ['', '(', '205', ')', '', ' ', '531', '-', '2332']
# obfuscate_line returns  (264) 565-2115
# obfuscate_line:  ['2000', ' ', 'SUMAC', ' ', 'CT']
# obfuscate_line returns  2188 SHMHH CT
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '4313']
# obfuscate_line returns  BEPXHEPAHTC OH 44192-4742
# obfuscate_line:  ['Karen', ' ', 'eastmank', '@', 'bellsouth', '.', 'net', ',', '', ' ', 'Bill', ' ', 'trainnutwb', '@', 'gmail', '.', 'com']
# obfuscate_line returns  Kevkv euwqwanx@bqqjjfenh.net, Bblp tsvjzoxmso@gkkpw.com
# obfuscate_line:  ['Karen', "'", 's', ' ', 'cell', ' ', '', '(', '205', ')', '', ' ', '531', '-', '2332', ',', '', ' ', 'Bill', "'", 's', ' ', 'cell', ' ', '', '(', '205', ')', '', ' ', '887', '-', '4329']
# obfuscate_line returns  Kyweh's cell (217) 583-2907, Bwat's cell (278) 833-4011
# obfuscate_line:  ['John', ' ', 'and', ' ', 'Debra', ' ', 'Barnett']
# obfuscate_line returns  Jksh and Dyjsi Bflvuse
# obfuscate_line:  ['3889', ' ', 'SUMMER', ' ', 'CHASE', ' ', 'CT']
# obfuscate_line returns  3430 SZPJVZ CLLXD CT
# obfuscate_line:  ['LAKE', ' ', 'WORTH', ' ', 'FL', ' ', '33467', '-', '2461']
# obfuscate_line returns  LZDM WSGAE FN 39150-2667
# obfuscate_line:  ['Brian', ' ', 'and', ' ', 'Melissa', ' ', 'Baumbarger']
# obfuscate_line returns  Bxqau and Mkxtqpe Bceibdlvet
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '609', '-', '7287']
# obfuscate_line returns  (919) 618-7925
# obfuscate_line:  ['1158', ' ', 'ANKENEY', ' ', 'RD']
# obfuscate_line returns  1667 AXJNHVC RD
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9533']
# obfuscate_line returns  XYAGZ OH 46886-9324
# obfuscate_line:  ['mtbaum12', '@', 'gmail', '.', 'com']
# obfuscate_line returns  mubiqv19@gorkf.com
# obfuscate_line:  ['Charles', ' ', 'and', ' ', 'Deborah', ' ', 'Bush']
# obfuscate_line returns  Cadkybb and Dlyptve Bins
# obfuscate_line:  ['2491', ' ', 'Beaver', ' ', 'Valley', ' ', 'Road']
# obfuscate_line returns  2858 Beeqxp Vglzii Rcvt
# obfuscate_line:  ['Beavercreek', ',', '', ' ', 'OH', ' ', '45434']
# obfuscate_line returns  Bzqkiumvtlz, OH 48980
# obfuscate_line:  ['Bertha', ' ', 'Buttner']
# obfuscate_line returns  Bnoyet Beepnfw
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '610', '-', '8757']
# obfuscate_line returns  (978) 645-8324
# obfuscate_line:  ['530', ' ', 'NEWPORT', ' ', 'RD', ' ', 'APT', ' ', '9C']
# obfuscate_line returns  570 NYFXZXQ RD APT 9Z
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '5230']
# obfuscate_line returns  XUKKZ OH 41472-5470
# obfuscate_line:  ['bebebuttner', '@', 'gmail', '.', 'com']
# obfuscate_line returns  bfjcpqwzalv@gphvu.com
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '919', '-', '3592']
# obfuscate_line returns  cell (981) 902-3080
# obfuscate_line:  ['Marian', ' ', 'Clark']
# obfuscate_line returns  Maehfx Cvlee
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '6299']
# obfuscate_line returns  (960) 494-6818
# obfuscate_line:  ['3541', ' ', 'Rosehill', ' ', 'Avenue']
# obfuscate_line returns  3103 Rqmmmqhs Aqmzhn
# obfuscate_line:  ['Beavercreek', ',', '', ' ', 'OH', ' ', '', ' ', '45440']
# obfuscate_line returns  Bmzmhfsclrv, OH  48266
# obfuscate_line:  ['golfer116', '@', 'aol', '.', 'com']
# obfuscate_line returns  galkef391@arq.com
# obfuscate_line:  ['Brian', ' ', 'and', ' ', 'Alice', ' ', 'Clausing']
# obfuscate_line returns  Btsdx and Awwpk Cqtxsudx
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '427', '-', '0849']
# obfuscate_line returns  (930) 487-0256
# obfuscate_line:  ['2097', ' ', 'FAIRKNOLL', ' ', 'DR']
# obfuscate_line returns  2249 FDECHNEMZ DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431']
# obfuscate_line returns  BWSDGFPHICS OH 45574
# obfuscate_line:  ['aclausing843', '@', 'gmail', '.', 'com']
# obfuscate_line returns  amornthxd440@gjnyx.com
# obfuscate_line:  ['Alice', "'", 's', ' ', 'cell', ' ', '', '(', '937', ')', '397', '-', '6309']
# obfuscate_line returns  Atslh's cell (913)337-6260
# obfuscate_line:  ['Steve', ' ', 'and', ' ', 'Trisha', ' ', 'Cole']
# obfuscate_line returns  Sarho and Tqlrmu Cfss
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '681', '-', '5310']
# obfuscate_line returns  (979) 664-5460
# obfuscate_line:  ['2300', ' ', 'EL', ' ', 'CID', ' ', 'DR']
# obfuscate_line returns  2405 EY CYO DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '2627']
# obfuscate_line returns  BOPKRYSIUDH OH 46003-2801
# obfuscate_line:  ['trishmcole', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  tjzonodrbq@yfbgp.com
# obfuscate_line:  ['Eleanor', ' ', 'Coleman']
# obfuscate_line returns  Eadjnbx Cmfubtk
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '4462']
# obfuscate_line returns  (983) 424-4487
# obfuscate_line:  ['1412', ' ', 'LONG', ' ', 'ISLAND', ' ', 'CT']
# obfuscate_line returns  1197 LJDA IQBYKU CT
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6923']
# obfuscate_line returns  BGRLDHKAPMA OH 43504-6623
# obfuscate_line:  ['lilbitrowdymy2cats', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  lsjlxlspdlfrm5vfhy@ytabp.com
# obfuscate_line:  ['Bill', ' ', 'and', ' ', 'Carolyn', ' ', 'Conner']
# obfuscate_line returns  Bhdr and Chqytod Cwhpob
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '5221']
# obfuscate_line returns  (983) 484-5508
# obfuscate_line:  ['3193', ' ', 'KINGFISHER', ' ', 'PL']
# obfuscate_line returns  3470 KMZRLDHSOA PA
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '3373']
# obfuscate_line returns  BOHHMPNUNTJ OH 45618-3667
# obfuscate_line:  ['carolyn', '.', 'conner', '@', 'gmail', '.', 'com', ';', 'bill', '.', 'conner', '@', 'gmail', '.', 'com']
# obfuscate_line returns  cglohvc.ctcpzu@giwog.com;bdve.cvwosu@gxjnn.com
# obfuscate_line:  ['Karen', ' ', 'Davidson']
# obfuscate_line returns  Knthf Dbbjtgkw
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '545', '-', '3413']
# obfuscate_line returns  (909) 514-3025
# obfuscate_line:  ['PO', ' ', 'BOX', ' ', '1162']
# obfuscate_line returns  PO BOX 1462
# obfuscate_line:  ['INVERNESS', ' ', 'FL', ' ', '34451', '-', '1162']
# obfuscate_line returns  IMSCCYJMF FV 34212-1031
# obfuscate_line:  ['kdavidson19', '@', 'tampabay', '.', 'rr', '.', 'com']
# obfuscate_line returns  kzdslihtx88@tpqeuzdc.rb.com
# obfuscate_line:  ['Timothy', ' ', 'and', ' ', 'Charmayne', ' ', 'Davis']
# obfuscate_line returns  Twcjlax and Cndidsslj Dtocr
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '367', '-', '5050']
# obfuscate_line returns  (964) 348-5340
# obfuscate_line:  ['1436', ' ', 'CROWN', ' ', 'POINT', ' ', 'CT']
# obfuscate_line returns  1230 CEOZQ PZZFO CT
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6965']
# obfuscate_line returns  BIZBEMGMGDM OH 45001-6044
# obfuscate_line:  ['may31st2us', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  mfv40da1ly@ybfqw.com
# obfuscate_line:  ['John', ' ', 'Deal']
# obfuscate_line returns  Jnjs Dwge
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '2118']
# obfuscate_line returns  (958) 487-2050
# obfuscate_line:  ['3444', ' ', 'DAYTON', ' ', 'XENIA', ' ', 'RD']
# obfuscate_line returns  3194 DNWJDS XVYVM RD
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2731']
# obfuscate_line returns  BDJFIVMRHCV OH 47051-2245
# obfuscate_line:  ['dealslandscape', '@', 'aol', '.', 'com']
# obfuscate_line returns  dsdfpfzboowyuo@akq.com
# obfuscate_line:  ['Elizabeth', ' ', 'Deitz']
# obfuscate_line returns  Eywplvslk Dfifd
# obfuscate_line:  ['', '(', '973', ')', '', ' ', '270', '-', '5206']
# obfuscate_line returns  (967) 260-5822
# obfuscate_line:  ['4414', ' ', 'Moraine', ' ', 'Ridge', ' ', 'Lane']
# obfuscate_line returns  4880 Mmwrfjm Rwtnt Loyf
# obfuscate_line:  ['Dayton', ' ', 'OH', ' ', '45429']
# obfuscate_line returns  Dpjguy OH 42139
# obfuscate_line:  ['Linda', ' ', 'Dolbeer']
# obfuscate_line returns  Llpps Dejtvrl
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '672', '-', '8743']
# obfuscate_line returns  (989) 641-8764
# obfuscate_line:  ['806', ' ', 'Spring', ' ', 'Lake', ' ', 'Circle', ' ', '']
# obfuscate_line returns  815 Sicpsn Lsfd Cscvyj
# obfuscate_line:  ['Enon', ' ', 'OH', ' ', '45323']
# obfuscate_line returns  Elgw OH 41159
# obfuscate_line:  ['gembass', '@', 'att', '.', 'net']
# obfuscate_line returns  gwbuact@ayi.net
# obfuscate_line:  ['Bertine', ' ', 'Dolkowski']
# obfuscate_line returns  Bjvbchp Dcoamtkxp
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '256', '-', '3834']
# obfuscate_line returns  (989) 227-3185
# obfuscate_line:  ['1379', ' ', 'LARAMIE', ' ', 'DR']
# obfuscate_line returns  1226 LUGCWXN DR
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45432', '-', '3135']
# obfuscate_line returns  DFACQH OH 48357-3623
# obfuscate_line:  ['Brian', ' ', 'Eastman', ' ', 'and', ' ', 'Amelia', ' ', 'O', "'", 'Dowd']
# obfuscate_line returns  Bkjyx Engujac and Arlrju O'Dofm
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '469', '-', '1383']
# obfuscate_line returns  (958) 476-1167
# obfuscate_line:  ['236', ' ', 'GREEN', ' ', 'ST']
# obfuscate_line returns  224 GHRQH ST
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45402', '-', '2936']
# obfuscate_line returns  DEZKZQ OH 47950-2236
# obfuscate_line:  ['pastorbrian', '@', 'beaverucc', '.', 'org']
# obfuscate_line returns  pyrdflcxeup@bqlqdqhvy.org
# obfuscate_line:  ['Nancy', ' ', 'Eastman']
# obfuscate_line returns  Nbzco Epiymac
# obfuscate_line:  ['6426', ' ', 'Brook', ' ', 'Village', ' ', 'Cove', ' ', '', '#', '301']
# obfuscate_line returns  6236 Bgvvv Vzpkxaz Chxy #331
# obfuscate_line:  ['Bradenton', ' ', 'FL', ' ', '34202']
# obfuscate_line returns  Bgtwbblus FP 36471
# obfuscate_line:  ['Scott', ' ', 'and', ' ', 'Jessica', ' ', 'Ervin']
# obfuscate_line returns  Sebfg and Jcdlpjh Ewomj
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '901', '-', '2895']
# obfuscate_line returns  (979) 951-2051
# obfuscate_line:  ['110', ' ', 'JONES', ' ', 'ST']
# obfuscate_line returns  103 JMCJE ST
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45410', '-', '1108']
# obfuscate_line returns  DXKSXA OH 46097-1017
# obfuscate_line:  ['support', '@', 'ervineducationalconsulting', '.', 'com']
# obfuscate_line returns  soxyonr@enhmiaazphdmxkujrqtykevwrz.com
# obfuscate_line:  ['Pat', ' ', 'Ferguson']
# obfuscate_line returns  Pyy Flijqcoq
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '4650']
# obfuscate_line returns  (901) 454-4366
# obfuscate_line:  ['1826', ' ', 'N', ' ', 'CENTRAL', ' ', 'DR']
# obfuscate_line returns  1209 N CGTWASV DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2012']
# obfuscate_line returns  BRMIYSQCGTU OH 40030-2020
# obfuscate_line:  ['patferguson28', '@', 'gmail', '.', 'com']
# obfuscate_line returns  platiguaidi39@godiw.com
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '654', '-', '7995']
# obfuscate_line returns  cell (997) 607-7823
# obfuscate_line:  ['Steve', ' ', 'Filer']
# obfuscate_line returns  Stzmy Fifeg
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '657', '-', '6079']
# obfuscate_line returns  (940) 668-6723
# obfuscate_line:  ['243', ' ', 'W', ' ', '3RD', ' ', 'ST']
# obfuscate_line returns  264 W 3IE ST
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '3535']
# obfuscate_line returns  XEMLU OH 49093-3374
# obfuscate_line:  ['slf302zee', '@', 'gmail', '.', 'com']
# obfuscate_line returns  swk067mza@gfmzz.com
# obfuscate_line:  ['Philip', ' ', 'and', ' ', 'Dolores', ' ', 'Frederick']
# obfuscate_line returns  Pyarbv and Dhmclbl Fdxojijxx
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '320', '-', '1098']
# obfuscate_line returns  (927) 382-1659
# obfuscate_line:  ['1645', ' ', 'Beaver', ' ', 'Valley', ' ', 'Rd', '.', '']
# obfuscate_line returns  1951 Bhzrlg Vumojx Rd.
# obfuscate_line:  ['Beavercreek', ',', '', ' ', 'Oh', ' ', '45434', '-', '6906']
# obfuscate_line returns  Bcwsmmqecvv, Oh 40867-6594
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '271', '-', '7461']
# obfuscate_line returns  cell (909) 239-7753
# obfuscate_line:  ['Mark', ' ', 'and', ' ', 'Pat', ' ', 'Freeze']
# obfuscate_line returns  Msoi and Puu Foifos
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '287', '-', '9738']
# obfuscate_line returns  (960) 257-9779
# obfuscate_line:  ['3789', ' ', 'BUTTERFIELD', ' ', 'DR']
# obfuscate_line returns  3084 BPSRXZXGJQW DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '2490']
# obfuscate_line returns  BGCOQPVZFZD OH 40429-2265
# obfuscate_line:  ['mpfreeze', '@', 'juno', '.', 'com']
# obfuscate_line returns  mdygefwl@jorf.com
# obfuscate_line:  ['Sara', ' ', 'French']
# obfuscate_line returns  Sxzu Fjpcfq
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '728', '-', '8889']
# obfuscate_line returns  (997) 702-8833
# obfuscate_line:  ['2451', ' ', 'TROTTER', ' ', 'CT']
# obfuscate_line returns  2495 TOIRRYN CT
# obfuscate_line:  ['BEAVERCREEK', ' ', 'TWP', ' ', 'OH', ' ', '45434']
# obfuscate_line returns  BRAKYSTYBQB TOQ OH 47993
# obfuscate_line:  ['Dolores', ' ', 'Gaudy']
# obfuscate_line returns  Diulrze Gbgzh
# obfuscate_line:  ['20', ' ', 'Gershwin', ' ', 'Drive']
# obfuscate_line returns  20 Goqaxakt Drive
# obfuscate_line:  ['Centerville', ',', '', ' ', 'OH', ' ', '45458']
# obfuscate_line returns  Cehutafxwvq, OH 48318
# obfuscate_line:  ['Christopher', ' ', 'and', ' ', 'Sarah', ' ', 'George']
# obfuscate_line returns  Ckabiwoqgch and Ssimv Goyaju
# obfuscate_line:  ['2899', ' ', 'LANTZ', ' ', 'RD']
# obfuscate_line returns  2400 LPFEV RD
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6657']
# obfuscate_line returns  BTRQEXBZAGF OH 48553-6450
# obfuscate_line:  ['Doug', ' ', 'and', ' ', 'Pat', ' ', 'Goudy']
# obfuscate_line returns  Dyfv and Pzp Gaysu
# obfuscate_line:  ['1620', ' ', 'S', ' ', 'Laddie', ' ', 'Ct']
# obfuscate_line returns  1479 S Lpxeif Ct
# obfuscate_line:  ['Dayton', ' ', 'OH', ' ', '45432']
# obfuscate_line returns  Dbegzm OH 40233
# obfuscate_line:  ['patigoudy', '@', 'gmail', '.', 'com']
# obfuscate_line returns  pjrugwjpz@gnqdz.com
# obfuscate_line:  ['Jean', ' ', 'Harshman']
# obfuscate_line returns  Jsks Hbdkmmnr
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '1028']
# obfuscate_line returns  (967) 460-1689
# obfuscate_line:  ['2501', ' ', 'BEAVER', ' ', 'VALLEY', ' ', 'RD']
# obfuscate_line returns  2285 BXUKHB VUTLWO RD
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6993']
# obfuscate_line returns  BTDDRVNHIUS OH 47081-6728
# obfuscate_line:  ['Jim', ' ', 'and', ' ', 'Jeri', ' ', 'Hawker']
# obfuscate_line returns  Jlx and Jlrs Hjloif
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '286', '-', '6000']
# obfuscate_line returns  (953) 284-6167
# obfuscate_line:  ['497', ' ', 'GRANGE', ' ', 'HALL', ' ', 'RD']
# obfuscate_line returns  458 GAZALE HFUX RD
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45430', '-', '2045']
# obfuscate_line returns  BTTRNCZSXFF OH 46516-2694
# obfuscate_line:  ['jerilynhawker', '@', 'icloud', '.', 'com']
# obfuscate_line returns  jziydnlpzdsxb@isudga.com
# obfuscate_line:  ['Keith', ' ', 'and', ' ', 'Barb', ' ', 'Hawkins']
# obfuscate_line returns  Knmok and Bsmr Hwstmfq
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '372', '-', '7420']
# obfuscate_line returns  (905) 333-7735
# obfuscate_line:  ['945', ' ', 'HAWKINS', ' ', 'RD']
# obfuscate_line returns  917 HOWMVJV RD
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9127']
# obfuscate_line returns  XEWCP OH 42611-9114
# obfuscate_line:  ['Lucas', ' ', 'and', ' ', 'Brittany', ' ', 'Hawkins']
# obfuscate_line returns  Lofpm and Bpbbawgz Hhyajta
# obfuscate_line:  ['710', ' ', 'HAWKINS', ' ', 'RD']
# obfuscate_line returns  770 HIICUIG RD
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9539']
# obfuscate_line returns  XZUGY OH 43138-9173
# obfuscate_line:  ['Carol', ' ', 'Hildebrecht']
# obfuscate_line returns  Ctqsm Hkozfylnnyl
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '307', '-', '1079']
# obfuscate_line returns  (982) 345-1207
# obfuscate_line:  ['2934', ' ', 'GREENCREST', ' ', 'DR']
# obfuscate_line returns  2494 GTZWCWOEVU DR
# obfuscate_line:  ['KETTERING', ' ', 'OH', ' ', '45432', '-', '3806']
# obfuscate_line returns  KMHXWPJWE OH 43516-3616
# obfuscate_line:  ['childebrecht', '@', 'roadrunner', '.', 'com']
# obfuscate_line returns  csecxyyeetwr@rhkaqlrftm.com
# obfuscate_line:  ['Sarah', ' ', 'Hogan']
# obfuscate_line returns  Smqjl Hmdum
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '681', '-', '9568']
# obfuscate_line returns  (949) 683-9407
# obfuscate_line:  ['4124', ' ', 'CARONDELET', ' ', 'DR']
# obfuscate_line returns  4414 CPSCLNNPDS DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45440', '-', '3215']
# obfuscate_line returns  BVOBVKWXSYS OH 49700-3210
# obfuscate_line:  ['Marjorie', ' ', 'Howard']
# obfuscate_line returns  Mcfctwtk Himsrt
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '376', '-', '3268']
# obfuscate_line returns  (912) 375-3941
# obfuscate_line:  ['831', ' ', 'JUNE', ' ', 'DR']
# obfuscate_line returns  841 JEBQ DR
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '3709']
# obfuscate_line returns  XKZJU OH 44977-3952
# obfuscate_line:  ['ffaith68', '@', 'aol', '.', 'com']
# obfuscate_line returns  fnqiyl82@aob.com
# obfuscate_line:  ['Margene', ' ', 'Howell']
# obfuscate_line returns  Mhguccm Hwarln
# obfuscate_line:  ['2795', ' ', 'Stauffer', ' ', 'Dr']
# obfuscate_line returns  2886 Szdcrkni Dr
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '45434', '-', '6261']
# obfuscate_line returns  Boggiizvxfn OH 46716-6235
# obfuscate_line:  ['Tim', ' ', 'and', ' ', 'Maria', ' ', 'Huddleston']
# obfuscate_line returns  Tue and Mdlhn Hzysclrocf
# obfuscate_line:  ['', '(', '513', ')', '', ' ', '485', '-', '9902']
# obfuscate_line returns  (534) 456-9843
# obfuscate_line:  ['2211', ' ', 'BANDIT', ' ', 'TRL']
# obfuscate_line returns  2678 BVSUTO TXQ
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '5678']
# obfuscate_line returns  BYROJAQHLQS OH 46203-5324
# obfuscate_line:  ['oshi76', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  ovsq76@ynccv.com
# obfuscate_line:  ['Tim', "'", 's', ' ', 'cell', ' ', '', '(', '513', ')', '', ' ', '485', '-', '9902', ',', '', ' ', 'Maria', "'", 's', ' ', 'cell', ' ', '', '(', '513', ')', '', ' ', '485', '-', '8402']
# obfuscate_line returns  Tlr's cell (538) 456-9054, Mhbeb's cell (571) 486-8537
# obfuscate_line:  ['Sam', ' ', 'and', ' ', 'Judy', ' ', 'Hudson']
# obfuscate_line returns  Sgp and Jsxl Hpesae
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '429', '-', '0455']
# obfuscate_line returns  (971) 490-0328
# obfuscate_line:  ['531', ' ', 'RIVERWOOD', ' ', 'DR']
# obfuscate_line returns  503 RVWVUKZOH DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45430', '-', '1645']
# obfuscate_line returns  BJPMDCEJDWG OH 41589-1164
# obfuscate_line:  ['hudson2658', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  hfwpus0132@sieeudoyp.net
# obfuscate_line:  ['Greg', ' ', 'and', ' ', 'Gloria', ' ', 'Hurwitz']
# obfuscate_line returns  Gnrp and Gwjnob Htipveu
# obfuscate_line:  ['761', ' ', 'CONSERVATION', ' ', 'CIR']
# obfuscate_line returns  776 CNUBMYBALIDO CCY
# obfuscate_line:  ['FAIRBORN', ' ', 'OH', ' ', '45324', '-', '4386']
# obfuscate_line returns  FGYFRBLH OH 42696-4270
# obfuscate_line:  ['Alex', ' ', 'Ignatiou']
# obfuscate_line returns  Adin Imuhzcik
# obfuscate_line:  ['', '(', '513', ')', '', ' ', '238', '-', '3711']
# obfuscate_line returns  (502) 207-3057
# obfuscate_line:  ['Mrs', '.', '', ' ', 'Robert', ' ', 'Jackson']
# obfuscate_line returns  Mhr. Rzolwq Jisfrnr
# obfuscate_line:  ['OAK', ' ', 'CREEK', ' ', 'TERRACE', '\n', '2316', ' ', 'SPRINGMILL', ' ', 'RD', ' ', '', '#', '', ' ', '124']
# obfuscate_line returns  OFJ CLTUD TYHKASC
# 2484 SYWDJDMORA RD # 130
# obfuscate_line:  ['KETTERING', ' ', 'OH', ' ', '45440', '-', '2504']
# obfuscate_line returns  KUYKSWRQQ OH 45494-2322
# obfuscate_line:  ['Mrs', '.', '', ' ', 'Richard', ' ', 'Kelly']
# obfuscate_line returns  Msm. Rsouizs Kzpux
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '372', '-', '7312']
# obfuscate_line returns  (916) 348-7563
# obfuscate_line:  ['1246', ' ', 'OLD', ' ', 'SPRINGFIELD', ' ', 'PIKE']
# obfuscate_line returns  1099 OPH SYREUYZWJBU PSNK
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '1242']
# obfuscate_line returns  XETEK OH 49258-1283
# obfuscate_line:  ['Kristen', ' ', 'King']
# obfuscate_line returns  Kcdrerb Kxml
# obfuscate_line:  ['4840', ' ', 'S', ' ', 'Juneau', ' ', 'St']
# obfuscate_line returns  4175 S Jikqjz St
# obfuscate_line:  ['Seattle', ' ', 'WA', ' ', '98118']
# obfuscate_line returns  Sasvcps WB 97827
# obfuscate_line:  ['theknking', '@', 'gmail', '.', 'com']
# obfuscate_line returns  thixrityq@ghpaf.com
# obfuscate_line:  ['Patti', ' ', 'King']
# obfuscate_line returns  Plowd Krst
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '776', '-', '8299']
# obfuscate_line returns  (975) 716-8338
# obfuscate_line:  ['2916', ' ', 'OAKLEY', ' ', 'AVE']
# obfuscate_line returns  2384 OLBPKY AMN
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45419', '-', '2043']
# obfuscate_line returns  DLXHZI OH 42639-2342
# obfuscate_line:  ['dramamamaking', '@', 'gmail', '.', 'com']
# obfuscate_line returns  duhghcstzrbwj@gwyfz.com
# obfuscate_line:  ['The', ' ', 'Rev', '.', '', ' ', 'and', ' ', 'Mrs', '.', '', ' ', 'Carl', ' ', 'W', '.', '', ' ', 'Knoch']
# obfuscate_line returns  Tvn Rif. and Mdk. Cpcw W. Khnzy
# obfuscate_line:  ['2077', ' ', 'VARTIKIAN', ' ', 'AVE']
# obfuscate_line returns  2388 VWODFGTIF AID
# obfuscate_line:  ['CLOVIS', ' ', 'CA', ' ', '93611', '-', '0654']
# obfuscate_line returns  CQXGVP CF 93582-0617
# obfuscate_line:  ['Byron', ' ', 'and', ' ', 'Anne', ' ', 'Kulander']
# obfuscate_line returns  Bttjs and Adjm Kosfuywj
# obfuscate_line:  ['24129', ' ', 'Winford', ' ', 'Square', ' ', 'Rd', ' ', '', '#', '2', '-', '5102']
# obfuscate_line returns  22198 Wboexmi Sjsagq Rd #2-5835
# obfuscate_line:  ['Kingwood', ' ', 'TX', ' ', '77339']
# obfuscate_line returns  Klneqmyg TQ 76839
# obfuscate_line:  ['aandbk', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  aocgmh@sazlkpyri.net
# obfuscate_line:  ['Chris', ' ', 'and', ' ', 'Terri', ' ', 'Kulander']
# obfuscate_line returns  Crjdf and Txrhi Kexzgiff
# obfuscate_line:  ['5731', ' ', 'GRAPE', ' ', 'ST']
# obfuscate_line returns  5049 GUBCW ST
# obfuscate_line:  ['HOUSTON', ' ', 'TX', ' ', '77096', '-', '1115']
# obfuscate_line returns  HGAOLPF TE 78836-1533
# obfuscate_line:  ['Sheila', ' ', 'Kwest']
# obfuscate_line returns  Ssirso Kpiyw
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '434', '-', '1737']
# obfuscate_line returns  (906) 477-1474
# obfuscate_line:  ['5137', ' ', 'Cloudsdale', ' ', 'Drive']
# obfuscate_line returns  5338 Clhgtzvkuo Drive
# obfuscate_line:  ['Kettering', ',', '', ' ', 'OH', ' ', '45440']
# obfuscate_line returns  Kktyycfdx, OH 46708
# obfuscate_line:  ['Greg', ' ', 'and', ' ', 'Joyce', ' ', 'Labenski']
# obfuscate_line returns  Gxcq and Jnvwe Lkfbvvpv
# obfuscate_line:  ['1273', ' ', 'WINDSOR', ' ', 'DR']
# obfuscate_line returns  1042 WXXQPJQ DR
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45434', '-', '8019']
# obfuscate_line returns  DFIYDN OH 40439-8189
# obfuscate_line:  ['Erik', ' ', 'and', ' ', 'Carol', ' ', 'Landing']
# obfuscate_line returns  Ehhc and Cljfq Lynprrf
# obfuscate_line:  ['855', ' ', 'AUTUMN', ' ', 'LEAF', ' ', 'DR']
# obfuscate_line returns  837 AGANOF LWMT DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45430', '-', '1493']
# obfuscate_line returns  BDFVXWPAZMI OH 46089-1346
# obfuscate_line:  ['erik', '.', 'landing', '@', 'hotmail', '.', 'com', ';', 'cwlanding', '@', 'woh', '.', 'rr', '.', 'com']
# obfuscate_line returns  eilx.llohfpn@hltoyus.com;cucvkyqqm@wwu.rc.com
# obfuscate_line:  ['Brett', ' ', 'and', ' ', 'Kendall', ' ', 'Landrum']
# obfuscate_line returns  Bgskg and Kvcfltm Lfwrftm
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '409', '-', '0997']
# obfuscate_line returns  (965) 401-0484
# obfuscate_line:  ['2552', ' ', 'Cross', ' ', 'Country', ' ', 'Rd']
# obfuscate_line returns  2735 Cwtye Cscxvym Rd
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '45431', '-', '8719']
# obfuscate_line returns  Bqqvaijibic OH 40772-8607
# obfuscate_line:  ['brettlandrum', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  btynjqvgmlns@ywqsu.com
# obfuscate_line:  ['Brett', "'", 's', ' ', 'cell', ' ', '', '(', '937', ')', '', ' ', '409', '-', '0997', ',', '', ' ', 'Kendal', "'", 's', ' ', 'cell', ' ', '', '(', '937', ')', '', ' ', '409', '-', '5527']
# obfuscate_line returns  Bndxo's cell (908) 406-0817, Kuddit's cell (971) 496-5036
# obfuscate_line:  ['James', ' ', 'Landrum']
# obfuscate_line returns  Jlmey Layqqpz
# obfuscate_line:  ['1600', ' ', 'HILLSIDE', ' ', 'DR']
# obfuscate_line returns  1148 HGOCEJUM DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2514']
# obfuscate_line returns  BPNSNPGLXTA OH 46440-2822
# obfuscate_line:  ['cluelessts', '@', 'aol', '.', 'com']
# obfuscate_line returns  czriokillz@art.com
# obfuscate_line:  ['Andrew', ' ', 'Lingenfelter']
# obfuscate_line returns  Avycur Lzainjtmiyjg
# obfuscate_line:  ['412', ' ', 'Brett', ' ', 'Dr']
# obfuscate_line returns  475 Bssfd Dr
# obfuscate_line:  ['Dayton', ' ', 'OH', ' ', '45433']
# obfuscate_line returns  Dpbyuh OH 49759
# obfuscate_line:  ['Kimberly', ' ', 'and', ' ', 'Burton', ' ', 'Lingenfelter']
# obfuscate_line returns  Kpzoqfep and Bqmkwd Lrrclcsptiwh
# obfuscate_line:  ['700', ' ', 'WALNUT', ' ', 'ST']
# obfuscate_line returns  788 WSTTKD ST
# obfuscate_line:  ['CHEROKEE', ' ', 'IA', ' ', '51012', '-', '1368']
# obfuscate_line returns  CGAQMEVZ IF 56919-1726
# obfuscate_line:  ['Lindsey', ' ', 'Lingenfelter']
# obfuscate_line returns  Ldtebid Lwutgaivmvzm
# obfuscate_line:  ['1418', ' ', 'Bareback', ' ', 'Trail']
# obfuscate_line returns  1137 Bdtahquc Turis
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '45434']
# obfuscate_line returns  Bopmhygbjcs OH 45270
# obfuscate_line:  ['John', ' ', 'Lyden']
# obfuscate_line returns  Jfni Lffkb
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '256', '-', '9776']
# obfuscate_line returns  (959) 216-9902
# obfuscate_line:  ['1152', ' ', 'SHARE', ' ', 'DR']
# obfuscate_line returns  1658 SLAWF DR
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45432', '-', '1741']
# obfuscate_line returns  DEDJHL OH 42165-1164
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '409', '-', '9776']
# obfuscate_line returns  cell (915) 437-9270
# obfuscate_line:  ['Tom', ' ', 'Maloney']
# obfuscate_line returns  Tri Maxhznd
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '938', '-', '5915']
# obfuscate_line returns  (915) 958-5832
# obfuscate_line:  ['5775', ' ', 'SHARP', ' ', 'RD']
# obfuscate_line returns  5911 SKPHG RD
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45432', '-', '1746']
# obfuscate_line returns  DQYUAH OH 49005-1840
# obfuscate_line:  ['Viola', ' ', 'Matyas']
# obfuscate_line returns  Viirr Mmxjrm
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '913', '-', '8071']
# obfuscate_line returns  (946) 918-8406
# obfuscate_line:  ['James', ' ', 'and', ' ', 'Sharon', ' ', 'Miller']
# obfuscate_line returns  Joret and Scggmt Muykke
# obfuscate_line:  ['PO', ' ', 'Box', ' ', '216', ' ', '', '\n', '638', ' ', 'North', ' ', '3rd', ' ', 'St']
# obfuscate_line returns  PO Box 201
# 601 Nkixp 3sj St
# obfuscate_line:  ['Hampton', ' ', 'NE', ' ', '68843']
# obfuscate_line returns  Hnvkaan NY 69573
# obfuscate_line:  ['Martin', ' ', 'and', ' ', 'Cathy', ' ', 'Miller']
# obfuscate_line returns  Mitlha and Ccjld Mcuwxg
# obfuscate_line:  ['PO', ' ', 'BOX', ' ', '105']
# obfuscate_line returns  PO BOX 174
# obfuscate_line:  ['ALPHA', ' ', 'OH', ' ', '45301', '-', '0105']
# obfuscate_line returns  ADHUS OH 48240-0057
# obfuscate_line:  ['cathyscraftycorner', '@', 'gmail', '.', 'com', ';', 'miller1328', '@', 'woh', '.', 'rr', '.', 'com']
# obfuscate_line returns  cysqzakbqcwohefzpb@gczjb.com;meyeeh0838@wqv.re.com
# obfuscate_line:  ['Alan', ' ', 'and', ' ', 'Shirley', ' ', 'Nelson']
# obfuscate_line returns  Ardh and Sndenql Nouftf
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '477', '-', '9355']
# obfuscate_line returns  (926) 440-9619
# obfuscate_line:  ['4207', ' ', 'COUNTRY', ' ', 'GLEN', ' ', 'CIR']
# obfuscate_line returns  4524 CNRIMVA GXYS CZF
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '4129']
# obfuscate_line returns  BHOWQIGGVOT OH 43746-4259
# obfuscate_line:  ['classictic', '@', 'aol', '.', 'com', ';', 'sjnelson1953', '@', 'gmail', '.', 'com']
# obfuscate_line returns  cuptichaxt@anl.com;seihmcju3235@gppmm.com
# obfuscate_line:  ['Ruth', ' ', 'Osborn']
# obfuscate_line returns  Rkzx Olbxhs
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '372', '-', '5422']
# obfuscate_line returns  (978) 358-5352
# obfuscate_line:  ['Friends', ' ', 'Care', ' ', 'Community', ',', '', '\n', '150', ' ', 'E', ' ', 'Herman', ' ', 'St']
# obfuscate_line returns  Fbmbcmj Cwwh Czoynmkjs,
# 105 E Hsdpws St
# obfuscate_line:  ['Yellow', ' ', 'Springs', ' ', 'OH', ' ', '45387']
# obfuscate_line returns  Yyaypx Suxfcfh OH 40679
# obfuscate_line:  ['Mary', ' ', 'Owens']
# obfuscate_line returns  Mdow Onstm
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '1917']
# obfuscate_line returns  (937) 419-1507
# obfuscate_line:  ['2368', ' ', 'LANTZ', ' ', 'RD']
# obfuscate_line returns  2782 LYSTO RD
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6802']
# obfuscate_line returns  BQEOFEJOOHN OH 46906-6003
# obfuscate_line:  ['rmowens2004', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  rjxuyfv9259@spvmnszmg.net
# obfuscate_line:  ['Nancy', ' ', 'Pack']
# obfuscate_line returns  Nlmuy Peak
# obfuscate_line:  ['2657', ' ', 'Cevennes', ' ', 'Terrace']
# obfuscate_line returns  2862 Cvrjpgbu Tngpjnn
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '45434']
# obfuscate_line returns  Bzoljianndh OH 47317
# obfuscate_line:  ['Jeannette', ' ', 'Papajcik']
# obfuscate_line returns  Jvcfbkdkc Peycjriz
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '478', '-', '8318']
# obfuscate_line returns  (939) 411-8463
# obfuscate_line:  ['2793', ' ', 'STEFAN', ' ', 'PL']
# obfuscate_line returns  2153 SBVVPY PJ
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45431', '-', '8492']
# obfuscate_line returns  DYTMRP OH 48461-8950
# obfuscate_line:  ['jpapajcik', '@', 'aol', '.', 'com']
# obfuscate_line returns  jpzkjqxxy@ahy.com
# obfuscate_line:  ['Robert', ' ', 'and', ' ', 'Barb', ' ', 'Penrod']
# obfuscate_line returns  Redbzy and Buya Pgzbje
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '6187']
# obfuscate_line returns  (957) 472-6693
# obfuscate_line:  ['1371', ' ', 'EILEEN', ' ', 'DR']
# obfuscate_line returns  1551 ELVTLI DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6562']
# obfuscate_line returns  BACARBYSDJW OH 42800-6705
# obfuscate_line:  ['rpenrod660', '@', 'gmail', '.', 'com', ';', 'epenrod930', '@', 'aol', '.', 'com']
# obfuscate_line returns  rsffsac288@gdftn.com;ehmeerh503@agv.com
# obfuscate_line:  ['Kristine', ' ', 'Petrick']
# obfuscate_line returns  Kdakhzcl Pzdlqgi
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '429', '-', '4857']
# obfuscate_line returns  (901) 429-4488
# obfuscate_line:  ['336', ' ', 'HONEY', ' ', 'JANE', ' ', 'DR']
# obfuscate_line returns  316 HKVKV JWNS DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '5715']
# obfuscate_line returns  BITIGGKWCZA OH 48822-5397
# obfuscate_line:  ['kristine', '.', 'petrick', '@', 'gmail', '.', 'com']
# obfuscate_line returns  kkcyiucd.punzrub@gpiyz.com
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '750', '-', '1603']
# obfuscate_line returns  cell (907) 715-1337
# obfuscate_line:  ['Bonnie', ' ', 'Phillips']
# obfuscate_line returns  Bhtcwb Poygypck
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '376', '-', '3133']
# obfuscate_line returns  (990) 330-3811
# obfuscate_line:  ['801', ' ', 'Nightingale', ' ', 'Cir']
# obfuscate_line returns  835 Nlkuevtmhrb Cwi
# obfuscate_line:  ['Xenia', ' ', 'OH', ' ', '45385', '-', '7262']
# obfuscate_line returns  Xoeun OH 47173-7266
# obfuscate_line:  ['Frank', ' ', 'Phillips']
# obfuscate_line returns  Faqqy Pnladukv
# obfuscate_line:  ['2604', ' ', 'Washington', ' ', 'Mill', ' ', 'Road']
# obfuscate_line returns  2651 Wzvnkxnldt Mbuq Rxon
# obfuscate_line:  ['Bellbrook', ',', '', ' ', 'OH', ' ', '', ' ', '45305']
# obfuscate_line returns  Bnreqdvjh, OH  46988
# obfuscate_line:  ['Blinda', ' ', 'Pickens']
# obfuscate_line returns  Bsiumv Pbjhsdv
# obfuscate_line:  ['823', ' ', 'Willard', ' ', 'St']
# obfuscate_line returns  882 Wxechoa St
# obfuscate_line:  ['Washington', ' ', 'Court', ' ', 'House', ' ', 'OH', ' ', '43160']
# obfuscate_line returns  Wadlbzdayq Cjour Hlavu OH 47688
# obfuscate_line:  ['Penny', ' ', 'Powell']
# obfuscate_line returns  Piija Pyjnio
# obfuscate_line:  ['', '(', '470', ')', '', ' ', '869', '-', '1925']
# obfuscate_line returns  (451) 886-1426
# obfuscate_line:  ['2625', ' ', 'Essex', ' ', 'Glen', ' ', 'Cove']
# obfuscate_line returns  2367 Ebdvd Gaqm Crmv
# obfuscate_line:  ['Comming', ' ', 'GA', ' ', '30040', '-', '3324']
# obfuscate_line returns  Cgfjdks GE 34230-3260
# obfuscate_line:  ['icemanjhp', '@', 'roadrunner', '.', 'com']
# obfuscate_line returns  iwlhfrlxz@rbhygjmutw.com
# obfuscate_line:  ['Jim', ' ', 'and', ' ', 'Denise', ' ', 'Powell']
# obfuscate_line returns  Jvg and Dnahdt Pdqasy
# obfuscate_line:  ['2540', ' ', 'Essex', ' ', 'Glen', ' ', 'Cove']
# obfuscate_line returns  2174 Eaalm Gbou Cfvx
# obfuscate_line:  ['Comming', ' ', 'GA', ' ', '30040', '-', '3324']
# obfuscate_line returns  Ctnqdvz GY 31531-3071
# obfuscate_line:  ['Judd', ' ', 'and', ' ', 'Michele', ' ', 'Powell']
# obfuscate_line returns  Jjtz and Meomgrx Pilmcs
# obfuscate_line:  ['1690', ' ', 'GRAND', ' ', 'PORTAGE', ' ', 'TRL']
# obfuscate_line returns  1165 GAQKJ PCNWDMR TJG
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9201']
# obfuscate_line returns  XNPZL OH 43452-9176
# obfuscate_line:  ['Austin', ' ', 'Puckett']
# obfuscate_line returns  Apgtib Pcfdawn
# obfuscate_line:  ['20', ' ', 'WYNDEMERE', ' ', 'DR']
# obfuscate_line returns  27 WVLCPAJQH DR
# obfuscate_line:  ['FRANKLIN', ' ', 'OH', ' ', '45005', '-', '2434']
# obfuscate_line returns  FMRMEJRI OH 45462-2526
# obfuscate_line:  ['Carl', ' ', 'and', ' ', 'Angela', ' ', 'Puckett']
# obfuscate_line returns  Cylw and Arikax Plonuzj
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '236', '-', '2981']
# obfuscate_line returns  (945) 287-2353
# obfuscate_line:  ['3567', ' ', 'CYPRESS', ' ', 'POINTE', ' ', 'DR']
# obfuscate_line returns  3003 CUKESOD PZXSYD DR
# obfuscate_line:  ['BELLBROOK', ' ', 'OH', ' ', '45305', '-', '7521']
# obfuscate_line returns  BASMTCJZB OH 45214-7961
# obfuscate_line:  ['carldpuckett', '@', 'aol', '.', 'com']
# obfuscate_line returns  clmmncarvxay@afi.com
# obfuscate_line:  ['Margaret', ' ', 'Puckett']
# obfuscate_line returns  Mgwiewke Psnsvhz
# obfuscate_line:  ['1170', ' ', 'BELLBROOK', ' ', 'AVE']
# obfuscate_line returns  1258 BSKZZUWES AZX
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '4014']
# obfuscate_line returns  XEYKQ OH 46261-4043
# obfuscate_line:  ['cell', ' ', '', '(', '937', ')', '', ' ', '902', '-', '8620']
# obfuscate_line returns  cell (925) 919-8196
# obfuscate_line:  ['Linda', ' ', 'Racz']
# obfuscate_line returns  Lrmmk Rcme
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '607', '-', '4745']
# obfuscate_line returns  (924) 694-4270
# obfuscate_line:  ['2475', ' ', 'Lillian', ' ', 'Lane', ',', '', ' ', 'Apt', '.', '', ' ', '202']
# obfuscate_line returns  2800 Ltvetzh Lszt, Apt. 270
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431']
# obfuscate_line returns  BGVEYLWJISN OH 45159
# obfuscate_line:  ['desi63linda', '@', 'aol', '.', 'com']
# obfuscate_line returns  dvck89hfgip@aqk.com
# obfuscate_line:  ['Edward', ' ', 'and', ' ', 'Jenny', ' ', 'Rauch']
# obfuscate_line returns  Ecyfzy and Jogna Rcsur
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '429', '-', '2853']
# obfuscate_line returns  (982) 413-2963
# obfuscate_line:  ['3837', ' ', 'WINTHROP', ' ', 'DR']
# obfuscate_line returns  3182 WZMABTDV DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '3153']
# obfuscate_line returns  BEFIRMGKHFN OH 44478-3495
# obfuscate_line:  ['jenrau65', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  jskewn85@sqlnioikx.net
# obfuscate_line:  ['Tom', ' ', 'and', ' ', 'Lisa', ' ', 'Rauls']
# obfuscate_line returns  Twp and Lfgm Rhhcv
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '6678']
# obfuscate_line returns  (928) 411-6975
# obfuscate_line:  ['2801', ' ', 'EDWIN', ' ', 'DR']
# obfuscate_line returns  2099 EWYNU DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45434', '-', '6425']
# obfuscate_line returns  BMRDOJHSKBC OH 42816-6357
# obfuscate_line:  ['tlmhdr', '@', 'yahoo', '.', 'com', ';', '5cheeseheads', '@', 'gmail', '.', 'com']
# obfuscate_line returns  tmmhxv@yynfc.com;5yrdhmasttve@glodc.com
# obfuscate_line:  ['Doug', ' ', 'and', ' ', 'Janice', ' ', 'Rice']
# obfuscate_line returns  Diuc and Jdlxfq Rzpf
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '427', '-', '9119']
# obfuscate_line returns  (918) 410-9421
# obfuscate_line:  ['3714', ' ', 'FINCASTLE', ' ', 'DR']
# obfuscate_line returns  3285 FBXPMWNPX DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '2428']
# obfuscate_line returns  BSFULWUCSMW OH 45905-2718
# obfuscate_line:  ['drice', '@', 'techeasesolutions', '.', 'com', ';', 'janice', '@', 'jriceapr', '.', 'com']
# obfuscate_line returns  dcgaf@tsrufrsmchytozxtu.com;jnustm@jwscslrd.com
# obfuscate_line:  ['Viola', ' ', 'Robertson']
# obfuscate_line returns  Vuhjr Rdnmklcbg
# obfuscate_line:  ['Shawnee', ' ', 'Estates', '\n', '60', ' ', 'Paceline', ' ', 'Ct', '.', '', ',', '', ' ', 'Rm', '#', '402']
# obfuscate_line returns  Srixoso Eouzthi
# 62 Prbqqtcj Ct., Ra#491
# obfuscate_line:  ['Xenia', ' ', 'OH', ' ', '45385']
# obfuscate_line returns  Xscwa OH 48173
# obfuscate_line:  ['Roger', ' ', 'and', ' ', 'Susan', ' ', 'Saddler']
# obfuscate_line returns  Rmnmo and Stila Scxvrkq
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '429', '-', '0983']
# obfuscate_line returns  (957) 404-0454
# obfuscate_line:  ['2346', ' ', 'S', ' ', 'OLD', ' ', 'OAKS', ' ', 'DR']
# obfuscate_line returns  2737 S OHH OLQU DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '2408']
# obfuscate_line returns  BTUETICOJCH OH 46353-2501
# obfuscate_line:  ['sjsaddler', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  sqodhmxvr@szuwvydzn.net
# obfuscate_line:  ['Robert', ' ', 'and', ' ', 'Shelby', ' ', 'Schoonover']
# obfuscate_line returns  Rbghsc and Srnhlg Snfzpzvygr
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '602', '-', '3343']
# obfuscate_line returns  (988) 648-3041
# obfuscate_line:  ['3379', ' ', 'FAIRWOOD', ' ', 'DR']
# obfuscate_line returns  3341 FZUPGXRJ DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2376']
# obfuscate_line returns  BFDGSPRKFJK OH 46706-2103
# obfuscate_line:  ['bschoon', '@', 'woh', '.', 'rr', '.', 'com']
# obfuscate_line returns  bcrzslq@wxy.rt.com
# obfuscate_line:  ['Dean', ' ', 'and', ' ', 'Melinda', ' ', 'Severtson']
# obfuscate_line returns  Djce and Mtagvio Stsfqdxme
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '232', '-', '5454']
# obfuscate_line returns  (907) 272-5484
# obfuscate_line:  ['3859', ' ', 'STRALEY', ' ', 'RD']
# obfuscate_line returns  3679 SPFJCOK RD
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9619']
# obfuscate_line returns  XZQST OH 41945-9942
# obfuscate_line:  ['deansevertson', '@', 'yahoo', '.', 'com', ';', 'mindysevertson', '@', 'sbcglobal', '.', 'net']
# obfuscate_line returns  dmadxltqbvpng@yctwh.com;mexcackystotih@sbnkosffc.net
# obfuscate_line:  ['Mindy', "'", 's', ' ', 'cell', ' ', '', '(', '937', ')', '231', '-', '4653']
# obfuscate_line returns  Mexze's cell (985)235-4950
# obfuscate_line:  ['Isabel', ' ', 'Shaffer']
# obfuscate_line returns  Ipibou Sfyqako
# obfuscate_line:  ['George', ' ', 'Shaw']
# obfuscate_line returns  Gufgbd Spil
# obfuscate_line:  ['11', ' ', 'Heaton', ' ', 'Ave']
# obfuscate_line returns  16 Hwfwdo Aqm
# obfuscate_line:  ['Dayton', ',', '', ' ', 'OH', ' ', '', ' ', '45410', '-', '1728']
# obfuscate_line returns  Dpqekp, OH  42265-1836
# obfuscate_line:  ['Cynthia', ' ', 'Sheppard', ' ', '', '&', '', ' ', 'Glen', ' ', 'Solomon', ' ', 'MD']
# obfuscate_line returns  Ctyvecg Sshufpqj & Gguj Spbtcky ME
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '439', '-', '2327']
# obfuscate_line returns  (977) 488-2866
# obfuscate_line:  ['1075', ' ', 'W', ' ', 'RAHN', ' ', 'RD']
# obfuscate_line returns  1236 W RLAN RD
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45429', '-', '2048']
# obfuscate_line returns  DNOXFR OH 45051-2814
# obfuscate_line:  ['Rxcommonsense', '@', 'aol', '.', 'com']
# obfuscate_line returns  Rmdfodfincdww@azv.com
# obfuscate_line:  ['cell', ' ', '', '(', '630', ')', '', ' ', '605', '-', '4814']
# obfuscate_line returns  cell (649) 645-4174
# obfuscate_line:  ['Paul', ' ', 'Simmons']
# obfuscate_line returns  Plaj Sqokzeo
# obfuscate_line:  ['3483', ' ', 'Lawson', ' ', 'Dr']
# obfuscate_line returns  3797 Lhgdht Dr
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '45432']
# obfuscate_line returns  Bwyhibrnmje OH 44157
# obfuscate_line:  ['Paul', ' ', 'and', ' ', 'Ellen', ' ', 'Siverling']
# obfuscate_line returns  Pybh and Epdqb Sgpmemrsc
# obfuscate_line:  ['1693', ' ', 'WOODS', ' ', 'DR']
# obfuscate_line returns  1436 WTAJU DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2268']
# obfuscate_line returns  BSFOWLMOBCE OH 42921-2305
# obfuscate_line:  ['siverlip', '@', 'msn', '.', 'com']
# obfuscate_line returns  soipoaqx@mvy.com
# obfuscate_line:  ['Elmer', ' ', 'and', ' ', 'Elinora', ' ', 'Smith']
# obfuscate_line returns  Elaxn and Erqimjr Smpfv
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '702', '-', '9485']
# obfuscate_line returns  (993) 717-9804
# obfuscate_line:  ['2000', ' ', 'SUMAC', ' ', 'CT']
# obfuscate_line returns  2008 SIRRD CT
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '4313']
# obfuscate_line returns  BDGTBPXHEXR OH 42015-4402
# obfuscate_line:  ['mlsmith1930', '@', 'aol', '.', 'com']
# obfuscate_line returns  mugcxth0746@aor.com
# obfuscate_line:  ['cell', ' ', '', '(', '216', ')', '', ' ', '233', '-', '0637']
# obfuscate_line returns  cell (241) 289-0875
# obfuscate_line:  ['Martha', ' ', 'Smith']
# obfuscate_line returns  Mdydkm Sctcq
# obfuscate_line:  ['6114', ' ', 'Cruxten', ' ', 'Dr']
# obfuscate_line returns  6369 Ciixdxb Dr
# obfuscate_line:  ['Huber', ' ', 'Heights', ' ', 'OH', ' ', '45424']
# obfuscate_line returns  Hadoc Hkmeuiu OH 43808
# obfuscate_line:  ['Chris', ' ', 'and', ' ', 'Jodi', ' ', 'Sperber']
# obfuscate_line returns  Czvmi and Jbqn Sgmgyjz
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '377', '-', '7000']
# obfuscate_line returns  (921) 378-7902
# obfuscate_line:  ['2400', ' ', 'PASSAGE', ' ', 'KEY', ' ', 'TRL']
# obfuscate_line returns  2258 PIOXDJP KUN TUO
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '9212']
# obfuscate_line returns  XGGXJ OH 44987-9960
# obfuscate_line:  ['Agnes', ' ', 'Stanislo']
# obfuscate_line returns  Asvuq Sityrzph
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '4007']
# obfuscate_line returns  (911) 468-4710
# obfuscate_line:  ['3333', ' ', 'DAYTON', ' ', 'XENIA', ' ', 'RD', ' ', 'STE', ' ', 'B']
# obfuscate_line returns  3026 DGATKE XDZYO RD SCZ B
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2764']
# obfuscate_line returns  BRQTNNMBLMP OH 42628-2532
# obfuscate_line:  ['Carla', ' ', 'Stevens']
# obfuscate_line returns  Comcu Sdzittu
# obfuscate_line:  ['4135', ' ', 'Fleetwood', ' ', 'Dr']
# obfuscate_line returns  4969 Fdphptfcq Dr
# obfuscate_line:  ['Dayton', ' ', 'OH', ' ', '45416']
# obfuscate_line returns  Dkfecu OH 40990
# obfuscate_line:  ['giac711', '@', 'hotmail', '.', 'com']
# obfuscate_line returns  gevg601@hpwrita.com
# obfuscate_line:  ['Sheryl', ' ', 'Stevens']
# obfuscate_line returns  Synktd Sjioxts
# obfuscate_line:  ['13819', ' ', 'Oxford', ' ', 'Drive']
# obfuscate_line returns  19045 Ovbcat Drive
# obfuscate_line:  ['Edmond', ' ', 'OK', ' ', '', ' ', '73103']
# obfuscate_line returns  Emvxon OS  75784
# obfuscate_line:  ['sherryaug55', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  sbffvwaco23@yrqno.com
# obfuscate_line:  ['Bob', ' ', 'and', ' ', 'Ruth', ' ', 'Tobias']
# obfuscate_line returns  Bxn and Rlfs Tcozcl
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '426', '-', '6868']
# obfuscate_line returns  (974) 417-6362
# obfuscate_line:  ['3134', ' ', 'CLAYDOR', ' ', 'DR']
# obfuscate_line returns  3404 CLSSWZS DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '3308']
# obfuscate_line returns  BDXKBZTTJPA OH 48243-3144
# obfuscate_line:  ['bobnrutht', '@', 'att', '.', 'net']
# obfuscate_line returns  befsebtpz@apy.net
# obfuscate_line:  ['Eric', ' ', 'and', ' ', 'Rebecca', ' ', 'Tobias']
# obfuscate_line returns  Ewqc and Rhfdqhw Trqxoe
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '626', '-', '4871']
# obfuscate_line returns  (989) 605-4301
# obfuscate_line:  ['1106', ' ', 'DORCHESTER', ' ', 'RD']
# obfuscate_line returns  1131 DMPTFIEDOF RD
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '8523']
# obfuscate_line returns  XNPXG OH 46344-8872
# obfuscate_line:  ['Rebecca', ' ', 'Patton', ' ', 'Tobias', ' ', 'MD']
# obfuscate_line returns  Rbwfsgg Pzkdde Tqwfic MD
# obfuscate_line:  ['Gretchen', ' ', 'Weiler']
# obfuscate_line returns  Gjwivrop Wcchku
# obfuscate_line:  ['', '(', '703', ')', '', ' ', '595', '-', '6111']
# obfuscate_line returns  (728) 572-6646
# obfuscate_line:  ['3075', ' ', 'Ashton', ' ', 'Brooke', ' ', 'Drive', ',', '', ' ', 'Apt', ' ', '2']
# obfuscate_line returns  3013 Anlbfm Bugtqc Drive, Apt 2
# obfuscate_line:  ['Beavercreek', ' ', 'OH', ' ', '', ' ', '45431']
# obfuscate_line returns  Bdfyvencgfd OH  48422
# obfuscate_line:  ['glw1978', '@', 'yahoo', '.', 'com']
# obfuscate_line returns  gco6764@ytomn.com
# obfuscate_line:  ['Rev', '.', '', ' ', 'J', '.', '', ' ', 'Stuart', ' ', 'and', ' ', 'Rev', '.', '', ' ', 'Gail', ' ', 'Wells']
# obfuscate_line returns  Rfx. J. Sitsdr and Rff. Gjcb Wgtkw
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '912', '-', '5319']
# obfuscate_line returns  (973) 970-5711
# obfuscate_line:  ['2544', ' ', 'GREENSIDE', ' ', 'DR']
# obfuscate_line returns  2044 GTYFTAVEI DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45431', '-', '8602']
# obfuscate_line returns  BVFEEILNSWB OH 41150-8122
# obfuscate_line:  ['wellsjstu', '@', 'gmail', '.', 'com', ';', 'wellsga26', '@', 'gmail', '.', 'com']
# obfuscate_line returns  wuowwyzme@gzzvh.com;wlsjhlj24@gaeil.com
# obfuscate_line:  ['Gail', "'", 's', ' ', 'cell', ' ', '513', '-', '460', '-', '8567']
# obfuscate_line returns  Gcyx's cell 542-411-8616
# obfuscate_line:  ['Mark', ' ', 'and', ' ', 'Lori', ' ', 'Wieland']
# obfuscate_line returns  Mcpz and Lqdq Wvfzdiy
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '974', '-', '4762']
# obfuscate_line returns  (966) 956-4991
# obfuscate_line:  ['3352', ' ', 'WITHERSPOON', ' ', 'DR']
# obfuscate_line returns  3685 WCGYVQMAGRU DR
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45440', '-', '1571']
# obfuscate_line returns  DSBPOG OH 42670-1263
# obfuscate_line:  ['lteller2006', '@', 'gmail', '.', 'com']
# obfuscate_line returns  lytxazs8189@gtmfw.com
# obfuscate_line:  ['Robert', ' ', 'Willhelm']
# obfuscate_line returns  Rotgbg Wmaqhnng
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '602', '-', '9626']
# obfuscate_line returns  (902) 663-9433
# obfuscate_line:  ['3206', ' ', 'HARWOOD', ' ', 'ST']
# obfuscate_line returns  3498 HIZYCRB ST
# obfuscate_line:  ['DAYTON', ' ', 'OH', ' ', '45429', '-', '4217']
# obfuscate_line returns  DBQZTQ OH 49609-4627
# obfuscate_line:  ['ducatibob95', '@', 'gmail', '.', 'com']
# obfuscate_line returns  dscyeoqsj68@gsjcx.com
# obfuscate_line:  ['Rev', '.', '', ' ', 'Charles', ' ', 'Williams', ' ', 'Jr', '.', '', ' ', 'and', ' ', 'Sonya', ' ', 'Kirkwood', '-', 'Williams']
# obfuscate_line returns  Rox. Cvstzob Wdshaeuj Jc. and Srpdw Ktxagjaw-Wvptkmqw
# obfuscate_line:  ['', '(', '937', ')', '', ' ', '830', '-', '6034']
# obfuscate_line returns  (992) 870-6822
# obfuscate_line:  ['3070', ' ', 'HIGHLANDER', ' ', 'DR']
# obfuscate_line returns  3712 HPWQTCTGFK DR
# obfuscate_line:  ['BEAVERCREEK', ' ', 'OH', ' ', '45432', '-', '2475']
# obfuscate_line returns  BZROWMSQSRW OH 46964-2381
# obfuscate_line:  ['shakertownfarm', '@', 'gmail', '.', 'com']
# obfuscate_line returns  szzsfdwwxyajcv@gvtqe.com
# obfuscate_line:  ['Gina', ' ', 'Yarber']
# obfuscate_line returns  Gkbr Ylzeun
# obfuscate_line:  ['1174', ' ', 'N', ' ', 'DETROIT', ' ', 'ST']
# obfuscate_line returns  1313 N DOTEYIC ST
# obfuscate_line:  ['XENIA', ' ', 'OH', ' ', '45385', '-', '1931']
# obfuscate_line returns  XWBOY OH 41540-1395
# obfuscate_line:  ['lilfisch', '@', 'hotmail', '.', 'com']
# obfuscate_line returns  lvrjmskd@hcjhozd.com
